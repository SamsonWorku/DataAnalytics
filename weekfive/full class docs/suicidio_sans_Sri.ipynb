# %%
import os
import sys
print(sys.executable)
# Out:
# C:\ProgramData\Anaconda3\python.exe

# %%
#!pip install wordcloud

# %%
import numpy as np
 
import matplotlib.pyplot as plt
% matplotlib inline

import PIL as pillow
#import worldcloud
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import pandas as pd

# %%
import nltk
from nltk.tokenize import word_tokenize # as wt
from nltk.tokenize import sent_tokenize
from nltk.tokenize import TweetTokenizer
from nltk.probability import FreqDist
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer 
from nltk.sentiment.vader import SentimentIntensityAnalyzer

#this is sample data
from nltk.corpus import names  

from string import punctuation

#if the next cell does not work
#remove number symbol on following lines and re-run this cell
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('names')
nltk.download('stopwords')
nltk.download('vader_lexicon')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\nltk\twitter\__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\GBTC406015ur\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\GBTC406015ur\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package names to
# [nltk_data]     C:\Users\GBTC406015ur\AppData\Roaming\nltk_data...
# [nltk_data]   Package names is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\GBTC406015ur\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\GBTC406015ur\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
os.getcwd()
# Out:
# 'C:\\Users\\GBTC406015ur\\Documents'

# %%
df = pd.read_excel('.\datasets\one year of twitter suicide  tweets.xlsx')

# %%
df.head()
# Out:
#                                              content
# 0  If you or someone you know is struggling or in...
# 1  Iâ€™ve thinking about suicide every single day...
# 2                  This is how you write a headline.
# 3  How is suicide the biggest killer of boys unde...
# 4  Someone might need these contacts today: \n\nS...

# %%
df.count()
# Out:
# content    1856
# dtype: int64

# %%
#dataframe that does not (~) h

df_play = df[~df.content.str.contains('Sri')]
df_play = df_play[~df.content.str.contains('Lan*')]
df_play = df_play[~df.content.str.contains('bombers')]
df_play = df_play[~df.content.str.contains('killed')]
df_play = df_play[~df.content.str.contains('bombing')]
df_play = df_play[~df.content.str.contains('attacks')]
df_play = df_play[~df.content.str.contains('easter')]
df_play = df_play[~df.content.str.contains('Sunday')]
df_play = df_play[~df.content.str.contains('lan*')]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   import sys
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   # Remove the CWD from sys.path while we load stuff.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   # This is added back by InteractiveShellApp.init_path()

# %%
df_play.count()
# Out:
# content    913
# dtype: int64

# %%
df_play.head()
# Out:
#                                              content
# 0  If you or someone you know is struggling or in...
# 1  Iâ€™ve thinking about suicide every single day...
# 2                  This is how you write a headline.
# 3  How is suicide the biggest killer of boys unde...
# 4  Someone might need these contacts today: \n\nS...

# %%
df.dropna()

# %%
df_content = df[['content']]

# %%
df_content.head()
# Out:
#                                              content
# 0  If you or someone you know is struggling or in...
# 1  Iâ€™ve thinking about suicide every single day...
# 2                  This is how you write a headline.
# 3  How is suicide the biggest killer of boys unde...
# 4  Someone might need these contacts today: \n\nS...

# %%
string = []

#for item in content['].items():
#    string.append[item]

my_string = ' '.join(df_play['content'].tolist())

# %%
wctext = my_string.lower()

# %%
tknz_wct = word_tokenize(wctext)

# %%
len(tknz_wct)
# Out:
# 31586

# %%
tknz_wct[:10]
# Out:
# ['if', 'you', 'or', 'someone', 'you', 'know', 'is', 'struggling', 'or', 'in']

# %%
fd_wct = FreqDist(tknz_wct)
fd_wct
# Out:
# FreqDist({'if': 94,
#           'you': 312,
#           'or': 83,
#           'someone': 58,
#           'know': 52,
#           'is': 388,
#           'struggling': 11,
#           'in': 379,
#           'crisis': 51,
#           ',': 868,
#           'are': 178,
#           'not': 161,
#           'alone': 17,
#           '.': 1325,
#           'our': 71,
#           'partner': 4,
#           'lifeline': 17,
#           '@': 207,
#           '800273talk': 4,
#           'can': 85,
#           'help': 60,
#           'iâ€™ve': 8,
#           'thinking': 7,
#           'about': 119,
#           'suicide': 888,
#           'every': 37,
#           'single': 7,
#           'day': 71,
#           'i': 326,
#           'hate': 6,
#           'myself': 10,
#           'and': 520,
#           'want': 28,
#           'to': 734,
#           'be': 142,
#           'cut': 7,
#           'into': 28,
#           'pieces': 4,
#           'one': 89,
#           'way': 30,
#           'do': 96,
#           'this': 227,
#           '...': 69,
#           'how': 62,
#           'write': 6,
#           'a': 577,
#           'headline': 1,
#           'the': 811,
#           'biggest': 10,
#           'killer': 7,
#           'of': 531,
#           'boys': 12,
#           'under': 7,
#           '30': 7,
#           'country': 13,
#           'but': 138,
#           'itâ€™s': 28,
#           'never': 50,
#           'talked': 1,
#           'what': 61,
#           'an': 64,
#           'absolute': 2,
#           'sin': 2,
#           'might': 18,
#           'need': 63,
#           'these': 29,
#           'contacts': 4,
#           'today': 39,
#           ':': 283,
#           '-': 89,
#           '0800567567': 5,
#           'rape': 7,
#           '0214479762': 5,
#           'assault': 7,
#           '0861322322': 6,
#           'depression': 51,
#           '0800121314': 5,
#           'emergency': 5,
#           '112': 4,
#           'adhd': 4,
#           'helpline': 7,
#           '0800554433': 4,
#           'trauma': 16,
#           'line': 44,
#           '0800205026': 5,
#           'mental': 71,
#           'health': 61,
#           '0112344837': 4,
#           '#': 333,
#           'rippieterhowes': 1,
#           'pieterhowes': 1,
#           'fuck': 12,
#           'everyone': 11,
#           'who': 131,
#           'has': 63,
#           'some': 27,
#           'dumb': 1,
#           'shit': 12,
#           'say': 39,
#           'fucking': 9,
#           'selfish': 6,
#           'ass': 3,
#           'mfs': 1,
#           'friends': 45,
#           'prayer': 4,
#           'request': 2,
#           'on': 170,
#           'my': 154,
#           'minister': 6,
#           'family': 31,
#           'whose': 4,
#           'adult': 3,
#           'son': 8,
#           'just': 77,
#           'died': 41,
#           'by': 129,
#           'please': 91,
#           'ask': 10,
#           'godâ€™s': 1,
#           'loving': 2,
#           'presence': 1,
#           'for': 276,
#           'them': 61,
#           'thx': 1,
#           'appreciated': 2,
#           'dah': 2,
#           'agak': 1,
#           'cerita': 1,
#           'ni': 2,
#           'lebih': 1,
#           'promote': 4,
#           'dari': 1,
#           'bring': 7,
#           'awareness': 24,
#           'tapi': 1,
#           'masa': 1,
#           'tweet': 26,
#           'kata': 1,
#           'tak': 1,
#           'best': 14,
#           'so': 92,
#           'many': 42,
#           'came': 6,
#           'its': 20,
#           'defence': 2,
#           'distraught': 1,
#           'mother': 4,
#           'warns': 1,
#           'over': 31,
#           'netflix': 4,
#           "'s": 132,
#           '13': 7,
#           'reasons': 6,
#           'why': 46,
#           'after': 69,
#           'daughter': 3,
#           '12': 2,
#           'took': 15,
#           'her': 51,
#           'own': 18,
#           'lifeâ': 1,
#           '|': 6,
#           'daily': 5,
#           'mail': 2,
#           'online': 7,
#           'isnâ€™t': 10,
#           'real': 32,
#           '?': 178,
#           'then': 12,
#           'tell': 17,
#           'me': 98,
#           'lost': 33,
#           'at': 122,
#           '17.': 1,
#           'ever': 21,
#           'battles': 1,
#           'fighting': 10,
#           'their': 85,
#           'head': 8,
#           'forget': 5,
#           'check': 10,
#           'your': 84,
#           'loved': 22,
#           'ones': 8,
#           'proud': 12,
#           'music': 7,
#           'enjoy': 5,
#           '!': 191,
#           'other': 24,
#           'people': 112,
#           'think': 34,
#           'taste': 1,
#           'now': 42,
#           'woke': 1,
#           'up': 61,
#           'opens': 2,
#           'twitter': 32,
#           'ou': 1,
#           'mah': 1,
#           'gawd': 1,
#           'o': 4,
#           'answer': 12,
#           '2.': 2,
#           'all': 70,
#           'night': 5,
#           'double': 10,
#           'skwad': 1,
#           'karen': 1,
#           'fukuhara': 1,
#           '(': 87,
#           'squad': 19,
#           'she-ra': 1,
#           'princesses': 1,
#           'power': 4,
#           ')': 98,
#           '26.': 1,
#           'javert': 1,
#           'pit': 2,
#           'pic.twitter.com/vc2yiqqags': 1,
#           'hardly': 1,
#           'home': 15,
#           'always': 16,
#           'reppinâ€™': 1,
#           'matters': 3,
#           'month': 10,
#           'rt': 25,
#           'case': 9,
#           'needs': 10,
#           '0800': 26,
#           '14': 3,
#           'sadag': 1,
#           'south': 2,
#           'african': 1,
#           'anxiety': 11,
#           'group': 13,
#           'â': 4,
#           '567â': 1,
#           '567': 1,
#           'sms': 1,
#           '31393': 1,
#           'sa': 1,
#           '0861': 1,
#           '322â': 1,
#           '322': 1,
#           'two': 15,
#           'tone': 1,
#           'suit': 1,
#           'like': 58,
#           'joker': 2,
#           'harley': 2,
#           'quinn': 2,
#           'wears': 1,
#           'choker': 1,
#           'let': 21,
#           'doors': 1,
#           'patiently': 1,
#           'waiting': 6,
#           'hoteldiablo': 1,
#           'urgent': 1,
#           'father': 10,
#           'jesus': 5,
#           'holy': 3,
#           'spirit': 1,
#           'god': 20,
#           'save': 14,
#           'most': 23,
#           'precious': 2,
#           'younger': 2,
#           'brother': 20,
#           'ray17278912': 1,
#           'from': 93,
#           'suicidal': 16,
#           'thoughts': 23,
#           'any': 17,
#           'attempted': 8,
#           'guide': 4,
#           'him': 41,
#           'his': 86,
#           'seek': 10,
#           'urgently': 1,
#           'name': 7,
#           'mondaymotivation': 1,
#           'would': 70,
#           'shorten': 2,
#           'government': 8,
#           'reduce': 4,
#           'indigenous': 3,
#           'youth': 26,
#           'qanda': 1,
#           'russ_lynch': 1,
#           'iâ€™m': 18,
#           'new': 20,
#           'forgive': 3,
#           'tardy': 1,
#           'response': 3,
#           'youâ€™re': 9,
#           'brave': 1,
#           'man': 17,
#           'reporting': 5,
#           'devastating': 4,
#           'effects': 1,
#           '2019': 4,
#           'loan': 5,
#           'charge': 3,
#           '&': 115,
#           'commend': 1,
#           'given': 8,
#           'editor': 2,
#           'g.': 1,
#           'osborne': 1,
#           'gauke': 1,
#           'instigated': 1,
#           'retrospective': 3,
#           'tax': 5,
#           'pâ€™se': 1,
#           'keep': 17,
#           'investigati': 1,
#           'have': 128,
#           'been': 46,
#           'shaken': 1,
#           'silence': 10,
#           '22': 64,
#           'veterans': 86,
#           'commit': 103,
#           'mr': 2,
#           'shekhargupta': 1,
#           'article': 5,
#           'afridi': 1,
#           'writes': 5,
#           '``': 63,
#           'field': 3,
#           'orders': 2,
#           'india': 7,
#           'games': 2,
#           'were': 40,
#           'simple': 4,
#           'go': 29,
#           'destroy': 4,
#           'almost': 11,
#           'bomber': 20,
#           'does': 17,
#           "''": 74,
#           'allow': 1,
#           'theprintindia': 1,
#           'indian': 7,
#           'gambhir': 1,
#           'kaif': 1,
#           'wrote': 5,
#           'sports': 1,
#           'alexsha67667166': 1,
#           'without': 10,
#           'going': 17,
#           'war': 8,
#           'army..navy': 1,
#           'iaf': 1,
#           '7000+': 1,
#           'terrorist': 5,
#           'military': 6,
#           'personnel': 1,
#           'since': 12,
#           '2015': 1,
#           'highest': 8,
#           'army': 6,
#           'rate': 23,
#           'world': 17,
#           'terroristdeservesdeath': 1,
#           'give': 8,
#           'food': 5,
#           'bhikhari': 1,
#           'dont': 4,
#           'understand': 9,
#           'expect': 5,
#           'apologetic': 1,
#           'being': 39,
#           'hindu': 2,
#           'smritiirani': 1,
#           '.imo': 1,
#           'narendramodi': 2,
#           'govt': 8,
#           'threating': 1,
#           'break': 1,
#           'right': 12,
#           'yes': 6,
#           'youâ€™ll': 3,
#           'sad': 8,
#           'hurt': 10,
#           'canâ€™t': 13,
#           'threaten': 2,
#           'that': 215,
#           'kinda': 4,
#           'thing': 14,
#           'because': 48,
#           'it': 215,
#           'shittiest': 1,
#           'things': 14,
#           'rip': 2,
#           'mitch': 1,
#           'lucker': 1,
#           'episode': 11,
#           'aidan': 1,
#           'aftermath': 1,
#           'was': 120,
#           'saddest': 1,
#           'episodes': 1,
#           'aired': 1,
#           'corrie': 1,
#           'acting': 1,
#           'between': 6,
#           'cast': 3,
#           'member': 8,
#           'very': 23,
#           'raw': 1,
#           'emotional': 3,
#           'raised': 6,
#           'much': 27,
#           'with': 158,
#           'male': 5,
#           'hope': 12,
#           'wins': 1,
#           'award': 4,
#           'we': 146,
#           'ready': 4,
#           'conversation': 6,
#           'rates': 25,
#           'san': 3,
#           'tan': 1,
#           'valley': 1,
#           'no': 47,
#           'donâ€™t': 36,
#           'isabelle': 1,
#           'works': 3,
#           'spread': 5,
#           'around': 15,
#           'national': 27,
#           'prevention': 47,
#           '1': 27,
#           '800': 9,
#           '273': 3,
#           '8255': 4,
#           'ok': 5,
#           'ok.': 2,
#           "'re": 20,
#           'sensitive': 3,
#           'topics': 2,
#           'depressions': 1,
#           'only': 32,
#           'read': 9,
#           'risk': 18,
#           'hurts': 4,
#           'readin': 2,
#           'boy': 7,
#           'swear': 3,
#           'watching': 3,
#           'fans': 10,
#           'bits': 1,
#           'pudil': 1,
#           'hoops': 1,
#           'watched': 4,
#           'waddle': 1,
#           'hirst': 1,
#           'nilsson': 1,
#           'palmer': 1,
#           'sheridan': 1,
#           'watch': 15,
#           'weeks': 1,
#           'makeup': 1,
#           'filter': 1,
#           'feels': 5,
#           'nice': 4,
#           'happymonday': 1,
#           'stop': 16,
#           'killing': 7,
#           'girlfriends': 1,
#           'chuka': 1,
#           'university': 6,
#           'kills': 6,
#           'girlfriend': 3,
#           'kemu': 1,
#           'meru': 1,
#           'commits': 21,
#           'guardian': 1,
#           '2000-03-03': 1,
#           '1966': 1,
#           'california': 3,
#           'studied': 2,
#           'physicians': 2,
#           'attitudes': 1,
#           'toward': 1,
#           'sex-change': 1,
#           'surgery': 3,
#           'majority': 2,
#           'preferred': 2,
#           'desperate': 1,
#           'patients': 6,
#           'rather': 5,
#           'than': 45,
#           'undergo': 1,
#           'genital': 1,
#           'richard': 1,
#           'green': 6,
#           'nhs': 15,
#           'sex': 3,
#           'change': 13,
#           'programme': 2,
#           'pic.twitter.com/g9bxv9t70u': 1,
#           'mimorguee': 1,
#           'favorite': 3,
#           'dino': 1,
#           'set': 5,
#           'â€œdinosrawr': 1,
#           'â€\x9d': 5,
#           'see': 20,
#           'yourself': 10,
#           'front': 6,
#           'page': 7,
#           'http': 28,
#           '//suicidegirls.comâ': 4,
#           'opportunity': 3,
#           'reccomend': 1,
#           'anime': 1,
#           'enrich': 1,
#           'life': 72,
#           'which': 25,
#           "'ll": 12,
#           'start': 11,
#           'orange': 1,
#           'summary': 1,
#           'work': 17,
#           'together': 10,
#           'letters': 1,
#           'sent': 4,
#           'future': 4,
#           'friend': 23,
#           'when': 64,
#           'oscar': 2,
#           'despite': 3,
#           'outroar': 1,
#           'got': 13,
#           'nominated': 1,
#           'ca': 7,
#           "n't": 70,
#           'stress': 8,
#           'enough': 15,
#           'important': 12,
#           'week': 7,
#           'insight': 1,
#           '5': 14,
#           'courageous': 1,
#           'young': 26,
#           'talk': 17,
#           'they': 95,
#           'as': 79,
#           'teenagers': 1,
#           'stopped': 5,
#           'found': 12,
#           'path': 2,
#           'better': 11,
#           'listen': 9,
#           'insightsbs': 1,
#           'sbs': 1,
#           'sbsondemand': 1,
#           'maharshi..': 1,
#           'those': 28,
#           'farmers': 13,
#           'committed': 60,
#           'still': 25,
#           'survive': 2,
#           'maharshionmay9th': 1,
#           'directorvamshi': 1,
#           'too': 24,
#           'trolls': 4,
#           'hiding': 3,
#           'faces': 3,
#           'cowards': 2,
#           'behind': 6,
#           'fake': 3,
#           'profile': 1,
#           'pics': 1,
#           'contributing': 3,
#           'illness': 15,
#           '15-year-old': 6,
#           'rhys': 1,
#           'abandoned': 2,
#           'mum': 1,
#           'drug-addicted': 1,
#           'dad': 8,
#           'rhysâ€™': 1,
#           'reached': 3,
#           'low': 7,
#           'point': 13,
#           '17-year-old': 1,
#           'taken': 7,
#           'foster': 1,
#           'child': 11,
#           'heâ€™s': 9,
#           'happier': 1,
#           'loves': 1,
#           'riding': 1,
#           'bike': 1,
#           '+': 7,
#           'bent': 1,
#           'completing': 1,
#           'sydneytosurfers': 1,
#           'ride': 2,
#           'yotsaustralia': 1,
#           'seen': 5,
#           'mhere_mer': 1,
#           'suicidegirls': 6,
#           'yet': 9,
#           'click': 2,
#           'link': 2,
#           '//mhere.suicidegirls.comâ': 1,
#           'five': 3,
#           'years': 38,
#           'ago': 24,
#           'cousin': 1,
#           'remember': 15,
#           'love': 40,
#           'anything': 14,
#           'souled': 1,
#           'out': 46,
#           'thru': 4,
#           'breakup': 1,
#           'also': 23,
#           'listened': 1,
#           'during': 16,
#           'attempt': 21,
#           'made': 14,
#           'feel': 24,
#           'peace': 8,
#           'even': 25,
#           'darkest': 1,
#           'times': 15,
#           'jheneaiko': 1,
#           'producervsidol': 1,
#           'vote': 8,
#           'kiyora': 1,
#           '8th': 1,
#           'election': 3,
#           'ill': 7,
#           'take': 30,
#           'kneecaps': 1,
#           'ig': 1,
#           'wonâ€™t': 6,
#           'post': 12,
#           'again': 11,
#           'here': 23,
#           'ya': 3,
#           'goooo': 1,
#           'ð\x9d˜›ð\x9d˜©ð\x9d˜¦ð\x9d˜º': 3,
#           'ð\x9d˜¸ð\x9d˜ªð\x9d˜\xadð\x9d˜\xad': 4,
#           'ð\x9d˜¯ð\x9d˜°ð\x9d˜µ': 2,
#           'ð\x9d˜§ð\x9d˜°ð\x9d˜³ð\x9d˜¤ð\x9d˜¦': 1,
#           'ð\x9d˜¶ð\x9d˜´': 3,
#           'ð\x9d˜´ð\x9d˜µð\x9d˜°ð\x9d˜±': 1,
#           'ð\x9d˜¥ð\x9d˜¦ð\x9d˜¨ð\x9d˜³ð\x9d˜¢ð\x9d˜¥ð\x9d˜ªð\x9d˜¯ð\x9d˜¨': 1,
#           'ð\x9d˜¤ð\x9d˜°ð\x9d˜¯ð\x9d˜µð\x9d˜³ð\x9d˜°ð\x9d˜\xad': 1,
#           'ð\x9d˜žð\x9d˜¦': 1,
#           'ð\x9d˜£ð\x9d˜¦': 1,
#           'ð\x9d˜·ð\x9d˜ªð\x9d˜¤ð\x9d˜µð\x9d˜°ð\x9d˜³ð\x9d˜ªð\x9d˜°ð\x9d˜¶ð\x9d˜´': 1,
#           'ð\x9d˜œð\x9d˜±ð\x9d˜³ð\x9d˜ªð\x9d˜´ð\x9d˜ªð\x9d˜¯ð\x9d˜¨': 1,
#           'ð\x9d˜': 1,
#           '”': 25,
#           'ð\x9d˜¶ð\x9d˜´ð\x9d˜¦': 1,
#           'us': 39,
#           'vs.': 2,
#           'sequel': 1,
#           'coming': 9,
#           'soon': 4,
#           'client': 2,
#           'hearing': 6,
#           'went': 8,
#           'owing': 1,
#           'huge': 4,
#           'amount': 2,
#           'money': 6,
#           'end': 17,
#           'fight': 6,
#           'impact': 3,
#           'big': 4,
#           'business': 4,
#           'small': 7,
#           'disastrous': 1,
#           'tip': 1,
#           'dedicated': 5,
#           'damian': 2,
#           'homeless': 6,
#           'sneaks': 1,
#           'construction': 1,
#           'zone': 1,
#           'manages': 1,
#           'get': 47,
#           'crane': 1,
#           'had': 40,
#           'second': 6,
#           'amd': 1,
#           'wasnâ€™t': 6,
#           'able': 9,
#           'pull': 2,
#           'self': 12,
#           'may': 32,
#           'he': 87,
#           'rest': 4,
#           'jamieâ€™s': 1,
#           'leaving': 3,
#           'brienne': 1,
#           'obviously': 2,
#           'mission': 10,
#           'kill': 15,
#           'cersei': 2,
#           'close': 8,
#           'jamie': 1,
#           'coward': 1,
#           'hide': 4,
#           'north': 6,
#           'fire': 4,
#           'girl': 14,
#           'weâ€™': 1,
#           'd': 5,
#           'gameofthrones': 6,
#           'demthones': 1,
#           'crawl': 1,
#           'mouth': 2,
#           'grow': 5,
#           'flower': 3,
#           'tactical': 1,
#           'duckgame': 1,
#           'nintendoswitch': 2,
#           'â¦â¤': 1,
#           'tries': 2,
#           'push': 3,
#           'committing': 16,
#           'doctor': 2,
#           "'ve": 16,
#           'admitted': 4,
#           'muslims': 2,
#           'diabetes': 2,
#           'itu': 1,
#           'kidney': 1,
#           'stones': 1,
#           'problems': 5,
#           'attempts': 9,
#           'asthmatics': 1,
#           'refusing': 1,
#           'inhalers': 1,
#           'ramzan': 1,
#           'merciful': 1,
#           'fast': 2,
#           'exempt': 1,
#           'reason': 13,
#           'goodbye': 2,
#           'yesterday': 5,
#           'struggled': 2,
#           'kept': 4,
#           'gun': 17,
#           'impulsive': 2,
#           'act': 5,
#           'guns': 7,
#           'make': 30,
#           'permanent': 3,
#           'besmart': 2,
#           'depressionlies': 1,
#           'soukoku': 1,
#           'au': 3,
#           '7': 8,
#           '-wherein': 1,
#           'dazai': 3,
#           'seeks': 1,
#           'through': 17,
#           'blue': 4,
#           'sticky': 1,
#           'note': 14,
#           'posted': 3,
#           'pages': 1,
#           'book': 2,
#           'happy': 11,
#           'cheerful': 1,
#           'energetic': 1,
#           'dear': 7,
#           'students': 27,
#           'use': 15,
#           'escape': 1,
#           'stronger': 2,
#           'hold': 4,
#           'little': 11,
#           'more': 63,
#           'everything': 6,
#           'will': 46,
#           'pass': 2,
#           'age': 9,
#           'should': 26,
#           '$': 8,
#           '250': 1,
#           'coins': 1,
#           'scattered': 1,
#           'apartment': 1,
#           'body': 5,
#           'part': 7,
#           'bad': 10,
#           'murder-suicide': 8,
#           'pact': 8,
#           '3': 18,
#           'tgi': 1,
#           'fridays': 1,
#           'where': 15,
#           'longer': 8,
#           'welcome': 4,
#           'kinhongseok': 1,
#           'angst': 1,
#           'warning': 3,
#           'character': 5,
#           'death': 36,
#           'implications': 1,
#           'hongseok': 1,
#           'comes': 2,
#           'visit': 1,
#           'deceased': 1,
#           'lover': 2,
#           'hyunggu': 1,
#           'grave': 1,
#           'flowers': 2,
#           'apology': 1,
#           'letter': 2,
#           'oh': 3,
#           'yeah': 3,
#           'ppl': 5,
#           'excuse': 2,
#           'till': 1,
#           'extent': 2,
#           'pls': 1,
#           'tc': 1,
#           'word': 6,
#           'fun': 3,
#           'stupid': 2,
#           'wear': 2,
#           'red': 6,
#           'members': 14,
#           'community': 19,
#           'stolen': 1,
#           'specifically': 3,
#           'brotherâ€™s': 1,
#           'birth': 1,
#           'auntie': 1,
#           'friendâ€™s': 1,
#           'ruled': 3,
#           'werenâ€™t': 2,
#           'mmiw': 1,
#           'max': 1,
#           'discrimination': 1,
#           'proven': 2,
#           'research': 9,
#           'parent': 4,
#           'insists': 1,
#           'misgendering': 1,
#           'trans': 9,
#           'significantly': 4,
#           'increases': 6,
#           'judge': 2,
#           'ordering': 1,
#           'correct': 5,
#           'pronouns': 1,
#           'safeguards': 1,
#           'commited': 2,
#           'campus': 5,
#           'tonight': 7,
#           'theres': 1,
#           'anyone': 14,
#           'sort': 2,
#           'counsellors': 1,
#           'weekends': 1,
#           'vip': 1,
#           'snap': 1,
#           'https': 64,
#           '//reignhope.store/shop/lifetime-membershipâ': 1,
#           'â€¦': 39,
#           'sayin': 1,
#           'reeeally': 1,
#           'shitty': 2,
#           'mercy': 2,
#           'clips': 1,
#           'anyways': 1,
#           'â˜\x9dï¸ž': 2,
#           'õžà¨š': 1,
#           'õž': 1,
#           'pic.twitter.com/zymgxfoka0': 1,
#           'study': 11,
#           'says': 14,
#           'among': 12,
#           'ages': 3,
#           '10': 9,
#           '17': 1,
#           'surged': 1,
#           'year': 23,
#           'high': 14,
#           'show': 13,
#           'premiered': 1,
#           'taylors': 1,
#           'am': 23,
#           'heart': 21,
#           'broken': 7,
#           'words': 14,
#           'sexy': 1,
#           'sariaâ€™s': 1,
#           'wet': 1,
#           'wild': 2,
#           'â€œmizu': 1,
#           'odysseyâ€\x9d': 1,
#           'viewing': 1,
#           'pic.twitter.com/e0kxyqzmru': 1,
#           'tw//': 1,
#           'waking': 1,
#           'weird': 2,
#           'idk': 4,
#           'takes': 9,
#           'few': 5,
#           'hours': 4,
#           'realization': 2,
#           'hit': 4,
#           'horrifying': 1,
#           'angry': 2,
#           'devastated': 2,
#           'frustrated': 1,
#           'somewhat': 2,
#           'thankful': 1,
#           'dead': 12,
#           'unpfii': 2,
#           'speak': 6,
#           'issue': 7,
#           'hasnâ€™t': 3,
#           'improved': 1,
#           'first': 11,
#           '2003.': 1,
#           'highlighted': 1,
#           'un': 2,
#           'bodies': 2,
#           'statesâ€™': 1,
#           'technical': 1,
#           'financial': 2,
#           'assistance': 2,
#           'development': 2,
#           'replicable': 1,
#           'programs': 2,
#           'hi': 3,
#           '16k': 1,
#           'newbies': 1,
#           'thank': 37,
#           'support': 26,
#           'thanks': 7,
#           'hereâ€™s': 3,
#           'contest': 1,
#           'win': 8,
#           'exclusice': 1,
#           'a4': 1,
#           'print': 1,
#           'follow': 5,
#           '2': 17,
#           'winners': 2,
#           'pick': 1,
#           'wednesday': 1,
#           'open': 6,
#           'wide': 1,
#           'weak': 2,
#           'strong': 5,
#           'pain': 20,
#           'humour': 1,
#           'mothers': 2,
#           'wearing': 2,
#           'bombs': 2,
#           'children': 21,
#           'todayâ€™s': 3,
#           'terror': 4,
#           'threat': 2,
#           'numbers': 8,
#           'really': 20,
#           'prevent': 8,
#           'self-harm': 9,
#           'such': 9,
#           'assholes': 3,
#           'each': 10,
#           'surviving': 1,
#           'helicopter': 1,
#           'crash': 1,
#           'ayer': 2,
#           'ainâ€™t': 3,
#           'gsu19': 1,
#           'â€': 24,
#           '“': 10,
#           'georgia': 1,
#           'state': 12,
#           'closer': 1,
#           'view': 2,
#           'gorgeous': 2,
#           'cygnet': 1,
#           'photoset': 1,
#           'babycakes': 1,
#           '//bit.ly/2upuxw9â': 1,
#           'kids': 21,
#           'reach': 11,
#           'burden': 2,
#           'thatâ€™s': 6,
#           ...})

# %%
punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
#remove the punctuation
for word in tknz_wct:
    if word in punctuation:
        tknz_wct.remove(word)

# %%
len(tknz_wct)
# Out:
# 27974

# %%
eng_stopwords = stopwords.words('english')
eng_stopwords
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
rm_count = 0
new_words = []

for word in tknz_wct:
    if word not in eng_stopwords:# or "'s" or '``' or "''":
        new_words.append(word)
    else:
        rm_count += 1

# %%
len(new_words)
# Out:
# 17114

# %%
rm_count
# Out:
# 10860

# %%
fd_nw = FreqDist(new_words)
fd_nw.most_common(200)
# Out:
# [('suicide', 888),
#  ("'s", 132),
#  ('people', 112),
#  ('commit', 103),
#  ('please', 91),
#  ('#', 91),
#  ('one', 89),
#  ('veterans', 86),
#  ("''", 74),
#  ('life', 72),
#  ('day', 71),
#  ('mental', 71),
#  ('would', 70),
#  ("n't", 70),
#  ('...', 69),
#  ('22', 64),
#  ('https', 64),
#  ('need', 63),
#  ('``', 63),
#  ('health', 61),
#  ('help', 60),
#  ('committed', 60),
#  ('someone', 58),
#  ('like', 58),
#  ('know', 52),
#  ('crisis', 51),
#  ('depression', 51),
#  ('never', 50),
#  ('prevention', 47),
#  ('get', 47),
#  ('!', 47),
#  ('friends', 45),
#  ('men', 45),
#  ('line', 44),
#  ('many', 42),
#  ('died', 41),
#  ('love', 40),
#  ('today', 39),
#  ('say', 39),
#  ('us', 39),
#  ('â€¦', 39),
#  ('years', 38),
#  ('every', 37),
#  ('thank', 37),
#  ('donâ€™t', 36),
#  ('death', 36),
#  ('@', 36),
#  ('think', 34),
#  ('lost', 33),
#  ('real', 32),
#  ('twitter', 32),
#  ('may', 32),
#  ('family', 31),
#  ('way', 30),
#  ('take', 30),
#  ('make', 30),
#  ('800-273-8255', 30),
#  ('(', 30),
#  ('go', 29),
#  ('want', 28),
#  ('itâ€™s', 28),
#  ('http', 28),
#  ('uk', 28),
#  ('much', 27),
#  ('national', 27),
#  ('1', 27),
#  ('students', 27),
#  ('tweet', 26),
#  ('0800', 26),
#  ('youth', 26),
#  ('young', 26),
#  ('support', 26),
#  ('approximately', 26),
#  ('rt', 25),
#  ('rates', 25),
#  ('still', 25),
#  ('even', 25),
#  ('”', 25),
#  ('good', 25),
#  ('per', 25),
#  ('time', 25),
#  ('awareness', 24),
#  ('ago', 24),
#  ('feel', 24),
#  ('â€', 24),
#  ('die', 24),
#  ('thoughts', 23),
#  ('rate', 23),
#  ('friend', 23),
#  ('also', 23),
#  ('year', 23),
#  ('copy', 23),
#  ('138', 23),
#  ('least', 23),
#  ('.', 23),
#  ('loved', 22),
#  ('1619', 22),
#  ('care', 22),
#  ('ever', 21),
#  ('let', 21),
#  ('commits', 21),
#  ('attempt', 21),
#  ('heart', 21),
#  ('children', 21),
#  ('kids', 21),
#  ('god', 20),
#  ('brother', 20),
#  ('new', 20),
#  ('bomber', 20),
#  ("'re", 20),
#  ('see', 20),
#  ('pain', 20),
#  ('really', 20),
#  ('another', 20),
#  ('hotline', 20),
#  ('could', 20),
#  ('squad', 19),
#  ('community', 19),
#  ('thought', 19),
#  ('veteran', 19),
#  ('bullying', 19),
#  ('might', 18),
#  ('iâ€™m', 18),
#  ('risk', 18),
#  ('3', 18),
#  ('school', 18),
#  ('political', 18),
#  ('alone', 17),
#  ('lifeline', 17),
#  ('tell', 17),
#  ('man', 17),
#  ('keep', 17),
#  ('going', 17),
#  ('world', 17),
#  ('work', 17),
#  ('talk', 17),
#  ('end', 17),
#  ('gun', 17),
#  ('2', 17),
#  ('person', 17),
#  ("'m", 17),
#  ('gay', 17),
#  ('trauma', 16),
#  ('always', 16),
#  ('suicidal', 16),
#  ('stop', 16),
#  ('committing', 16),
#  ("'ve", 16),
#  ('call', 16),
#  ('women', 16),
#  ('took', 15),
#  ('home', 15),
#  ('two', 15),
#  ('around', 15),
#  ('watch', 15),
#  ('nhs', 15),
#  ('enough', 15),
#  ('illness', 15),
#  ('remember', 15),
#  ('times', 15),
#  ('kill', 15),
#  ('use', 15),
#  ('wife', 15),
#  ('lives', 15),
#  ('nigel', 15),
#  ('best', 14),
#  ('save', 14),
#  ('thing', 14),
#  ('things', 14),
#  ('5', 14),
#  ('anything', 14),
#  ('made', 14),
#  ('girl', 14),
#  ('note', 14),
#  ('members', 14),
#  ('anyone', 14),
#  ('says', 14),
#  ('high', 14),
#  ('words', 14),
#  ('story', 14),
#  ('saying', 14),
#  ('lgbtq', 14),
#  ('james', 14),
#  ('u', 14),
#  ('aas19', 14),
#  ('country', 13),
#  ('group', 13),
#  ('canâ€™t', 13),
#  ('change', 13),
#  ('got', 13),
#  ('farmers', 13),
#  ('point', 13),
#  ('reason', 13),
#  ('show', 13),
#  ('trying', 13),
#  ('parents', 13),
#  ('teen', 13),
#  ('dying', 13),
#  ('ptsd', 13),
#  ('problem', 13)]

# %%
rm_count = 0
final_words = []

for ugly_word in new_words:
    if ugly_word in ["'s","''",'``','@', '', 'â€¦','â€™' ,'”', '.','(',"'m", 'itâ€™s', '!', 'itâ€™s']:
        ugly_word = ' '
        final_words.append(ugly_word)
    #elseif ugly_word == 
    else:
        final_words.append(ugly_word)
        rm_count += 1

# %%
fd_nwFinal = FreqDist(final_words)
fd_nwFinal.most_common(100)
# Out:
# [('suicide', 888),
#  (' ', 515),
#  ('people', 112),
#  ('commit', 103),
#  ('please', 91),
#  ('#', 91),
#  ('one', 89),
#  ('veterans', 86),
#  ('life', 72),
#  ('day', 71),
#  ('mental', 71),
#  ('would', 70),
#  ("n't", 70),
#  ('...', 69),
#  ('22', 64),
#  ('https', 64),
#  ('need', 63),
#  ('health', 61),
#  ('help', 60),
#  ('committed', 60),
#  ('someone', 58),
#  ('like', 58),
#  ('know', 52),
#  ('crisis', 51),
#  ('depression', 51),
#  ('never', 50),
#  ('prevention', 47),
#  ('get', 47),
#  ('friends', 45),
#  ('men', 45),
#  ('line', 44),
#  ('many', 42),
#  ('died', 41),
#  ('love', 40),
#  ('today', 39),
#  ('say', 39),
#  ('us', 39),
#  ('years', 38),
#  ('every', 37),
#  ('thank', 37),
#  ('donâ€™t', 36),
#  ('death', 36),
#  ('think', 34),
#  ('lost', 33),
#  ('real', 32),
#  ('twitter', 32),
#  ('may', 32),
#  ('family', 31),
#  ('way', 30),
#  ('take', 30),
#  ('make', 30),
#  ('800-273-8255', 30),
#  ('go', 29),
#  ('want', 28),
#  ('http', 28),
#  ('uk', 28),
#  ('much', 27),
#  ('national', 27),
#  ('1', 27),
#  ('students', 27),
#  ('tweet', 26),
#  ('0800', 26),
#  ('youth', 26),
#  ('young', 26),
#  ('support', 26),
#  ('approximately', 26),
#  ('rt', 25),
#  ('rates', 25),
#  ('still', 25),
#  ('even', 25),
#  ('good', 25),
#  ('per', 25),
#  ('time', 25),
#  ('awareness', 24),
#  ('ago', 24),
#  ('feel', 24),
#  ('â€', 24),
#  ('die', 24),
#  ('thoughts', 23),
#  ('rate', 23),
#  ('friend', 23),
#  ('also', 23),
#  ('year', 23),
#  ('copy', 23),
#  ('138', 23),
#  ('least', 23),
#  ('loved', 22),
#  ('1619', 22),
#  ('care', 22),
#  ('ever', 21),
#  ('let', 21),
#  ('commits', 21),
#  ('attempt', 21),
#  ('heart', 21),
#  ('children', 21),
#  ('kids', 21),
#  ('god', 20),
#  ('brother', 20),
#  ('new', 20),
#  ('bomber', 20)]

# %%
len(fd_nwFinal)
# Out:
# 5525

# %%
fd_nwFinal
# Out:
# FreqDist({'someone': 58,
#           'know': 52,
#           'struggling': 11,
#           'crisis': 51,
#           'alone': 17,
#           'partner': 4,
#           'lifeline': 17,
#           '800273talk': 4,
#           'help': 60,
#           'iâ€™ve': 8,
#           'thinking': 7,
#           'suicide': 888,
#           'every': 37,
#           'single': 7,
#           'day': 71,
#           'hate': 6,
#           'want': 28,
#           'cut': 7,
#           'pieces': 4,
#           'one': 89,
#           'way': 30,
#           '...': 69,
#           'write': 6,
#           'headline': 1,
#           'biggest': 10,
#           'killer': 7,
#           'boys': 12,
#           '30': 7,
#           'country': 13,
#           ' ': 515,
#           'never': 50,
#           'talked': 1,
#           'absolute': 2,
#           'sin': 2,
#           'might': 18,
#           'need': 63,
#           'contacts': 4,
#           'today': 39,
#           '0800567567': 5,
#           'rape': 7,
#           '0214479762': 5,
#           'assault': 7,
#           '0861322322': 6,
#           'depression': 51,
#           '0800121314': 5,
#           'emergency': 5,
#           '112': 4,
#           'adhd': 4,
#           'helpline': 7,
#           '0800554433': 4,
#           'trauma': 16,
#           'line': 44,
#           '0800205026': 5,
#           'mental': 71,
#           'health': 61,
#           '0112344837': 4,
#           'rippieterhowes': 1,
#           'pieterhowes': 1,
#           'fuck': 12,
#           'everyone': 11,
#           'dumb': 1,
#           'shit': 12,
#           'say': 39,
#           'fucking': 9,
#           'selfish': 6,
#           'ass': 3,
#           'mfs': 1,
#           'friends': 45,
#           'prayer': 4,
#           'request': 2,
#           'minister': 6,
#           'family': 31,
#           'whose': 4,
#           'adult': 3,
#           'son': 8,
#           'died': 41,
#           'please': 91,
#           'ask': 10,
#           'godâ€™s': 1,
#           'loving': 2,
#           'presence': 1,
#           'thx': 1,
#           'appreciated': 2,
#           'dah': 2,
#           'agak': 1,
#           'cerita': 1,
#           'ni': 2,
#           'lebih': 1,
#           'promote': 4,
#           'dari': 1,
#           'bring': 7,
#           'awareness': 24,
#           'tapi': 1,
#           'masa': 1,
#           'tweet': 26,
#           'kata': 1,
#           'tak': 1,
#           'best': 14,
#           'many': 42,
#           'came': 6,
#           'defence': 2,
#           'distraught': 1,
#           'mother': 4,
#           'warns': 1,
#           'netflix': 4,
#           '13': 7,
#           'reasons': 6,
#           'daughter': 3,
#           '12': 2,
#           'took': 15,
#           'lifeâ': 1,
#           'daily': 5,
#           'mail': 2,
#           'online': 7,
#           'isnâ€™t': 10,
#           'real': 32,
#           'tell': 17,
#           'lost': 33,
#           '17.': 1,
#           'ever': 21,
#           'battles': 1,
#           'fighting': 10,
#           'head': 8,
#           'forget': 5,
#           'check': 10,
#           'loved': 22,
#           'ones': 8,
#           'proud': 12,
#           'music': 7,
#           'enjoy': 5,
#           'people': 112,
#           'think': 34,
#           'taste': 1,
#           'woke': 1,
#           'opens': 2,
#           'twitter': 32,
#           'ou': 1,
#           'mah': 1,
#           'gawd': 1,
#           'answer': 12,
#           '2.': 2,
#           'night': 5,
#           'double': 10,
#           'skwad': 1,
#           'karen': 1,
#           'fukuhara': 1,
#           'squad': 19,
#           'she-ra': 1,
#           'princesses': 1,
#           'power': 4,
#           '26.': 1,
#           'javert': 1,
#           'pit': 2,
#           'pic.twitter.com/vc2yiqqags': 1,
#           'hardly': 1,
#           'home': 15,
#           'always': 16,
#           'reppinâ€™': 1,
#           'matters': 3,
#           'month': 10,
#           'rt': 25,
#           'case': 9,
#           'needs': 10,
#           '0800': 26,
#           '14': 3,
#           'sadag': 1,
#           'south': 2,
#           'african': 1,
#           'anxiety': 11,
#           'group': 13,
#           'â': 4,
#           '567â': 1,
#           '567': 1,
#           'sms': 1,
#           '31393': 1,
#           'sa': 1,
#           '0861': 1,
#           '322â': 1,
#           '322': 1,
#           'two': 15,
#           'tone': 1,
#           'suit': 1,
#           'like': 58,
#           'joker': 2,
#           'harley': 2,
#           'quinn': 2,
#           'wears': 1,
#           'choker': 1,
#           'let': 21,
#           'doors': 1,
#           'patiently': 1,
#           'waiting': 6,
#           'hoteldiablo': 1,
#           'urgent': 1,
#           'father': 10,
#           'jesus': 5,
#           'holy': 3,
#           'spirit': 1,
#           'god': 20,
#           'save': 14,
#           'precious': 2,
#           'younger': 2,
#           'brother': 20,
#           'ray17278912': 1,
#           'suicidal': 16,
#           'thoughts': 23,
#           'attempted': 8,
#           'guide': 4,
#           'seek': 10,
#           'urgently': 1,
#           'name': 7,
#           'mondaymotivation': 1,
#           'would': 70,
#           'shorten': 2,
#           'government': 8,
#           'reduce': 4,
#           'indigenous': 3,
#           'youth': 26,
#           'qanda': 1,
#           'russ_lynch': 1,
#           'iâ€™m': 18,
#           'new': 20,
#           'forgive': 3,
#           'tardy': 1,
#           'response': 3,
#           'youâ€™re': 9,
#           'brave': 1,
#           'man': 17,
#           'reporting': 5,
#           'devastating': 4,
#           'effects': 1,
#           '2019': 4,
#           'loan': 5,
#           'charge': 3,
#           'commend': 1,
#           'given': 8,
#           'editor': 2,
#           'g.': 1,
#           'osborne': 1,
#           'gauke': 1,
#           'instigated': 1,
#           'retrospective': 3,
#           'tax': 5,
#           'pâ€™se': 1,
#           'keep': 17,
#           'investigati': 1,
#           'shaken': 1,
#           'silence': 10,
#           '22': 64,
#           'veterans': 86,
#           'commit': 103,
#           'mr': 2,
#           'shekhargupta': 1,
#           'article': 5,
#           'afridi': 1,
#           'writes': 5,
#           'field': 3,
#           'orders': 2,
#           'india': 7,
#           'games': 2,
#           'simple': 4,
#           'go': 29,
#           'destroy': 4,
#           'almost': 11,
#           'bomber': 20,
#           'allow': 1,
#           'theprintindia': 1,
#           'indian': 7,
#           'gambhir': 1,
#           'kaif': 1,
#           'wrote': 5,
#           'sports': 1,
#           'alexsha67667166': 1,
#           'without': 10,
#           'going': 17,
#           'war': 8,
#           'army..navy': 1,
#           'iaf': 1,
#           '7000+': 1,
#           'terrorist': 5,
#           'military': 6,
#           'personnel': 1,
#           'since': 12,
#           '2015': 1,
#           'highest': 8,
#           'army': 6,
#           'rate': 23,
#           'world': 17,
#           'terroristdeservesdeath': 1,
#           'give': 8,
#           'food': 5,
#           'bhikhari': 1,
#           'dont': 4,
#           'understand': 9,
#           'expect': 5,
#           'apologetic': 1,
#           'hindu': 2,
#           'smritiirani': 1,
#           '.imo': 1,
#           'narendramodi': 2,
#           'govt': 8,
#           'threating': 1,
#           'break': 1,
#           'right': 12,
#           'yes': 6,
#           'youâ€™ll': 3,
#           'sad': 8,
#           'hurt': 10,
#           'canâ€™t': 13,
#           'threaten': 2,
#           'kinda': 4,
#           'thing': 14,
#           'shittiest': 1,
#           'things': 14,
#           'rip': 2,
#           'mitch': 1,
#           'lucker': 1,
#           'episode': 11,
#           'aidan': 1,
#           'aftermath': 1,
#           'saddest': 1,
#           'episodes': 1,
#           'aired': 1,
#           'corrie': 1,
#           'acting': 1,
#           'cast': 3,
#           'member': 8,
#           'raw': 1,
#           'emotional': 3,
#           'raised': 6,
#           'much': 27,
#           'male': 5,
#           'hope': 12,
#           'wins': 1,
#           'award': 4,
#           'ready': 4,
#           'conversation': 6,
#           'rates': 25,
#           'san': 3,
#           'tan': 1,
#           'valley': 1,
#           'donâ€™t': 36,
#           'isabelle': 1,
#           'works': 3,
#           'spread': 5,
#           'around': 15,
#           'national': 27,
#           'prevention': 47,
#           '1': 27,
#           '800': 9,
#           '273': 3,
#           '8255': 4,
#           'ok': 5,
#           'ok.': 2,
#           "'re": 20,
#           'sensitive': 3,
#           'topics': 2,
#           'depressions': 1,
#           'read': 9,
#           'risk': 18,
#           'hurts': 4,
#           'readin': 2,
#           'boy': 7,
#           'swear': 3,
#           'watching': 3,
#           'fans': 10,
#           'bits': 1,
#           'pudil': 1,
#           'hoops': 1,
#           'watched': 4,
#           'waddle': 1,
#           'hirst': 1,
#           'nilsson': 1,
#           'palmer': 1,
#           'sheridan': 1,
#           'watch': 15,
#           'weeks': 1,
#           'makeup': 1,
#           'filter': 1,
#           'feels': 5,
#           'nice': 4,
#           'happymonday': 1,
#           'stop': 16,
#           'killing': 7,
#           'girlfriends': 1,
#           'chuka': 1,
#           'university': 6,
#           'kills': 6,
#           'girlfriend': 3,
#           'kemu': 1,
#           'meru': 1,
#           'commits': 21,
#           'guardian': 1,
#           '2000-03-03': 1,
#           '1966': 1,
#           'california': 3,
#           'studied': 2,
#           'physicians': 2,
#           'attitudes': 1,
#           'toward': 1,
#           'sex-change': 1,
#           'surgery': 3,
#           'majority': 2,
#           'preferred': 2,
#           'desperate': 1,
#           'patients': 6,
#           'rather': 5,
#           'undergo': 1,
#           'genital': 1,
#           'richard': 1,
#           'green': 6,
#           'nhs': 15,
#           'sex': 3,
#           'change': 13,
#           'programme': 2,
#           'pic.twitter.com/g9bxv9t70u': 1,
#           'mimorguee': 1,
#           'favorite': 3,
#           'dino': 1,
#           'set': 5,
#           'â€œdinosrawr': 1,
#           'â€\x9d': 5,
#           'see': 20,
#           'front': 6,
#           'page': 7,
#           'http': 28,
#           '//suicidegirls.comâ': 4,
#           'opportunity': 3,
#           'reccomend': 1,
#           'anime': 1,
#           'enrich': 1,
#           'life': 72,
#           "'ll": 12,
#           'start': 11,
#           'orange': 1,
#           'summary': 1,
#           'work': 17,
#           'together': 10,
#           'letters': 1,
#           'sent': 4,
#           'future': 4,
#           'friend': 23,
#           'oscar': 2,
#           'despite': 3,
#           'outroar': 1,
#           'got': 13,
#           'nominated': 1,
#           'ca': 7,
#           "n't": 70,
#           'stress': 8,
#           'enough': 15,
#           'important': 12,
#           'week': 7,
#           'insight': 1,
#           '5': 14,
#           'courageous': 1,
#           'young': 26,
#           'talk': 17,
#           'teenagers': 1,
#           'stopped': 5,
#           'found': 12,
#           'path': 2,
#           'better': 11,
#           'listen': 9,
#           'insightsbs': 1,
#           'sbs': 1,
#           'sbsondemand': 1,
#           'maharshi..': 1,
#           'farmers': 13,
#           'committed': 60,
#           'still': 25,
#           'survive': 2,
#           'maharshionmay9th': 1,
#           'directorvamshi': 1,
#           'trolls': 4,
#           'hiding': 3,
#           'faces': 3,
#           'cowards': 2,
#           'behind': 6,
#           'fake': 3,
#           'profile': 1,
#           'pics': 1,
#           'contributing': 3,
#           'illness': 15,
#           '15-year-old': 6,
#           'rhys': 1,
#           'abandoned': 2,
#           'mum': 1,
#           'drug-addicted': 1,
#           'dad': 8,
#           'rhysâ€™': 1,
#           'reached': 3,
#           'low': 7,
#           'point': 13,
#           '17-year-old': 1,
#           'taken': 7,
#           'foster': 1,
#           'child': 11,
#           'heâ€™s': 9,
#           'happier': 1,
#           'loves': 1,
#           'riding': 1,
#           'bike': 1,
#           'bent': 1,
#           'completing': 1,
#           'sydneytosurfers': 1,
#           'ride': 2,
#           'yotsaustralia': 1,
#           'seen': 5,
#           'mhere_mer': 1,
#           'suicidegirls': 6,
#           'yet': 9,
#           'click': 2,
#           'link': 2,
#           '//mhere.suicidegirls.comâ': 1,
#           'five': 3,
#           'years': 38,
#           'ago': 24,
#           'cousin': 1,
#           'remember': 15,
#           'love': 40,
#           'anything': 14,
#           'souled': 1,
#           'thru': 4,
#           'breakup': 1,
#           'also': 23,
#           'listened': 1,
#           'attempt': 21,
#           'made': 14,
#           'feel': 24,
#           'peace': 8,
#           'even': 25,
#           'darkest': 1,
#           'times': 15,
#           'jheneaiko': 1,
#           'producervsidol': 1,
#           'vote': 8,
#           'kiyora': 1,
#           '8th': 1,
#           'election': 3,
#           'ill': 7,
#           'take': 30,
#           'kneecaps': 1,
#           'ig': 1,
#           'wonâ€™t': 6,
#           'post': 12,
#           'ya': 3,
#           'goooo': 1,
#           'ð\x9d˜›ð\x9d˜©ð\x9d˜¦ð\x9d˜º': 3,
#           'ð\x9d˜¸ð\x9d˜ªð\x9d˜\xadð\x9d˜\xad': 4,
#           'ð\x9d˜¯ð\x9d˜°ð\x9d˜µ': 2,
#           'ð\x9d˜§ð\x9d˜°ð\x9d˜³ð\x9d˜¤ð\x9d˜¦': 1,
#           'ð\x9d˜¶ð\x9d˜´': 3,
#           'ð\x9d˜´ð\x9d˜µð\x9d˜°ð\x9d˜±': 1,
#           'ð\x9d˜¥ð\x9d˜¦ð\x9d˜¨ð\x9d˜³ð\x9d˜¢ð\x9d˜¥ð\x9d˜ªð\x9d˜¯ð\x9d˜¨': 1,
#           'ð\x9d˜¤ð\x9d˜°ð\x9d˜¯ð\x9d˜µð\x9d˜³ð\x9d˜°ð\x9d˜\xad': 1,
#           'ð\x9d˜žð\x9d˜¦': 1,
#           'ð\x9d˜£ð\x9d˜¦': 1,
#           'ð\x9d˜·ð\x9d˜ªð\x9d˜¤ð\x9d˜µð\x9d˜°ð\x9d˜³ð\x9d˜ªð\x9d˜°ð\x9d˜¶ð\x9d˜´': 1,
#           'ð\x9d˜œð\x9d˜±ð\x9d˜³ð\x9d˜ªð\x9d˜´ð\x9d˜ªð\x9d˜¯ð\x9d˜¨': 1,
#           'ð\x9d˜': 1,
#           'ð\x9d˜¶ð\x9d˜´ð\x9d˜¦': 1,
#           'us': 39,
#           'vs.': 2,
#           'sequel': 1,
#           'coming': 9,
#           'soon': 4,
#           'client': 2,
#           'hearing': 6,
#           'went': 8,
#           'owing': 1,
#           'huge': 4,
#           'amount': 2,
#           'money': 6,
#           'end': 17,
#           'fight': 6,
#           'impact': 3,
#           'big': 4,
#           'business': 4,
#           'small': 7,
#           'disastrous': 1,
#           'tip': 1,
#           'dedicated': 5,
#           'damian': 2,
#           'homeless': 6,
#           'sneaks': 1,
#           'construction': 1,
#           'zone': 1,
#           'manages': 1,
#           'get': 47,
#           'crane': 1,
#           'second': 6,
#           'amd': 1,
#           'wasnâ€™t': 6,
#           'able': 9,
#           'pull': 2,
#           'self': 12,
#           'may': 32,
#           'rest': 4,
#           'jamieâ€™s': 1,
#           'leaving': 3,
#           'brienne': 1,
#           'obviously': 2,
#           'mission': 10,
#           'kill': 15,
#           'cersei': 2,
#           'close': 8,
#           'jamie': 1,
#           'coward': 1,
#           'hide': 4,
#           'north': 6,
#           'fire': 4,
#           'girl': 14,
#           'weâ€™': 1,
#           'gameofthrones': 6,
#           'demthones': 1,
#           'crawl': 1,
#           'mouth': 2,
#           'grow': 5,
#           'flower': 3,
#           'tactical': 1,
#           'duckgame': 1,
#           'nintendoswitch': 2,
#           'â¦â¤': 1,
#           'tries': 2,
#           'push': 3,
#           'committing': 16,
#           'doctor': 2,
#           "'ve": 16,
#           'admitted': 4,
#           'muslims': 2,
#           'diabetes': 2,
#           'itu': 1,
#           'kidney': 1,
#           'stones': 1,
#           'problems': 5,
#           'attempts': 9,
#           'asthmatics': 1,
#           'refusing': 1,
#           'inhalers': 1,
#           'ramzan': 1,
#           'merciful': 1,
#           'fast': 2,
#           'exempt': 1,
#           'reason': 13,
#           'goodbye': 2,
#           'yesterday': 5,
#           'struggled': 2,
#           'kept': 4,
#           'gun': 17,
#           'impulsive': 2,
#           'act': 5,
#           'guns': 7,
#           'make': 30,
#           'permanent': 3,
#           'besmart': 2,
#           'depressionlies': 1,
#           'soukoku': 1,
#           'au': 3,
#           '7': 8,
#           '-wherein': 1,
#           'dazai': 3,
#           'seeks': 1,
#           'blue': 4,
#           'sticky': 1,
#           'note': 14,
#           'posted': 3,
#           'pages': 1,
#           'book': 2,
#           'happy': 11,
#           'cheerful': 1,
#           'energetic': 1,
#           'dear': 7,
#           'students': 27,
#           'use': 15,
#           'escape': 1,
#           'stronger': 2,
#           'hold': 4,
#           'little': 11,
#           'everything': 6,
#           'pass': 2,
#           'age': 9,
#           '250': 1,
#           'coins': 1,
#           'scattered': 1,
#           'apartment': 1,
#           'body': 5,
#           'part': 7,
#           'bad': 10,
#           'murder-suicide': 8,
#           'pact': 8,
#           '3': 18,
#           'tgi': 1,
#           'fridays': 1,
#           'longer': 8,
#           'welcome': 4,
#           'kinhongseok': 1,
#           'angst': 1,
#           'warning': 3,
#           'character': 5,
#           'death': 36,
#           'implications': 1,
#           'hongseok': 1,
#           'comes': 2,
#           'visit': 1,
#           'deceased': 1,
#           'lover': 2,
#           'hyunggu': 1,
#           'grave': 1,
#           'flowers': 2,
#           'apology': 1,
#           'letter': 2,
#           'oh': 3,
#           'yeah': 3,
#           'ppl': 5,
#           'excuse': 2,
#           'till': 1,
#           'extent': 2,
#           'pls': 1,
#           'tc': 1,
#           'word': 6,
#           'fun': 3,
#           'stupid': 2,
#           'wear': 2,
#           'red': 6,
#           'members': 14,
#           'community': 19,
#           'stolen': 1,
#           'specifically': 3,
#           'brotherâ€™s': 1,
#           'birth': 1,
#           'auntie': 1,
#           'friendâ€™s': 1,
#           'ruled': 3,
#           'werenâ€™t': 2,
#           'mmiw': 1,
#           'max': 1,
#           'discrimination': 1,
#           'proven': 2,
#           'research': 9,
#           'parent': 4,
#           'insists': 1,
#           'misgendering': 1,
#           'trans': 9,
#           'significantly': 4,
#           'increases': 6,
#           'judge': 2,
#           'ordering': 1,
#           'correct': 5,
#           'pronouns': 1,
#           'safeguards': 1,
#           'commited': 2,
#           'campus': 5,
#           'tonight': 7,
#           'theres': 1,
#           'anyone': 14,
#           'sort': 2,
#           'counsellors': 1,
#           'weekends': 1,
#           'vip': 1,
#           'snap': 1,
#           'https': 64,
#           '//reignhope.store/shop/lifetime-membershipâ': 1,
#           'sayin': 1,
#           'reeeally': 1,
#           'shitty': 2,
#           'mercy': 2,
#           'clips': 1,
#           'anyways': 1,
#           'â˜\x9dï¸ž': 2,
#           'õžà¨š': 1,
#           'õž': 1,
#           'pic.twitter.com/zymgxfoka0': 1,
#           'study': 11,
#           'says': 14,
#           'among': 12,
#           'ages': 3,
#           '10': 9,
#           '17': 1,
#           'surged': 1,
#           'year': 23,
#           'high': 14,
#           'show': 13,
#           'premiered': 1,
#           'taylors': 1,
#           'heart': 21,
#           'broken': 7,
#           'words': 14,
#           'sexy': 1,
#           'sariaâ€™s': 1,
#           'wet': 1,
#           'wild': 2,
#           'â€œmizu': 1,
#           'odysseyâ€\x9d': 1,
#           'viewing': 1,
#           'pic.twitter.com/e0kxyqzmru': 1,
#           'tw//': 1,
#           'waking': 1,
#           'weird': 2,
#           'idk': 4,
#           'takes': 9,
#           'hours': 4,
#           'realization': 2,
#           'hit': 4,
#           'horrifying': 1,
#           'angry': 2,
#           'devastated': 2,
#           'frustrated': 1,
#           'somewhat': 2,
#           'thankful': 1,
#           'dead': 12,
#           'unpfii': 2,
#           'speak': 6,
#           'issue': 7,
#           'hasnâ€™t': 3,
#           'improved': 1,
#           'first': 11,
#           '2003.': 1,
#           'highlighted': 1,
#           'un': 2,
#           'bodies': 2,
#           'statesâ€™': 1,
#           'technical': 1,
#           'financial': 2,
#           'assistance': 2,
#           'development': 2,
#           'replicable': 1,
#           'programs': 2,
#           'hi': 3,
#           '16k': 1,
#           'newbies': 1,
#           'thank': 37,
#           'support': 26,
#           'thanks': 7,
#           'hereâ€™s': 3,
#           'contest': 1,
#           'win': 8,
#           'exclusice': 1,
#           'a4': 1,
#           'print': 1,
#           'follow': 5,
#           '2': 17,
#           'winners': 2,
#           'pick': 1,
#           'wednesday': 1,
#           'open': 6,
#           'wide': 1,
#           'weak': 2,
#           'strong': 5,
#           'pain': 20,
#           'humour': 1,
#           'mothers': 2,
#           'wearing': 2,
#           'bombs': 2,
#           'children': 21,
#           'todayâ€™s': 3,
#           'terror': 4,
#           'threat': 2,
#           'numbers': 8,
#           'really': 20,
#           'prevent': 8,
#           'self-harm': 9,
#           'assholes': 3,
#           'surviving': 1,
#           'helicopter': 1,
#           'crash': 1,
#           'ayer': 2,
#           'ainâ€™t': 3,
#           'gsu19': 1,
#           'â€': 24,
#           '“': 10,
#           'georgia': 1,
#           'state': 12,
#           'closer': 1,
#           'view': 2,
#           'gorgeous': 2,
#           'cygnet': 1,
#           'photoset': 1,
#           'babycakes': 1,
#           '//bit.ly/2upuxw9â': 1,
#           'kids': 21,
#           'reach': 11,
#           'burden': 2,
#           'thatâ€™s': 6,
#           'literally': 8,
#           'exist': 1,
#           'experiencing': 3,
#           'moment': 9,
#           'scary': 1,
#           'corbyn': 3,
#           'trying': 13,
#           'agreement': 2,
#           'brexit': 2,
#           'deal': 12,
#           'bullied': 9,
#           'throughout': 1,
#           'elementary': 1,
#           'school': 18,
#           'losing': 9,
#           'parents': 13,
#           'aunties': 1,
#           'cousins': 2,
#           'diagnosed': 3,
#           's/o': 1,
#           'everyday': 6,
#           'another': 20,
#           'mentalhealthmonth': 2,
#           'falling': 3,
#           'form': 3,
#           'childhood': 1,
#           'mine': 1,
#           'respect': 4,
#           'asian': 1,
#           'idea': 4,
#           'posting': 1,
#           'share': 10,
#           'men': 45,
#           'existence': 1,
#           'letâ€™s': 2,
#           'telling': 7,
#           'niggas': 1,
#           'whew': 1,
#           'mishandling': 1,
#           'amongst': 2,
#           'continues': 3,
#           'â€œevening': 1,
#           'standard': 2,
#           'news': 11,
#           'content': 4,
#           'grid.â€\x9d': 1,
#           'journalism': 2,
#           'model': 2,
#           'left': 8,
#           'feelings': 3,
#           '=/=': 1,
#           'threatening': 2,
#           'thought': 19,
#           'iâ€™d': 5,
#           'shocking': 4,
#           'staggering': 1,
#           'infographics': 1,
#           'menâ€™s': 1,
#           'statistics': 3,
#           'fellow': 3,
#           'brethren': 1,
#           'okay': 6,
#           'become': 6,
#           'statistic': 4,
#           'concept': 1,
#           'art': 1,
#           'chuu': 1,
#           'lesbians': 2,
#           'good': 25,
#           'decided': 5,
#           'gays': 1,
#           'well': 12,
#           'ive': 3,
#           'youve': 1,
#           'done': 10,
#           'others': 11,
#           'pic.twitter.com/l0igxbws6s': 1,
#           'felt': 5,
#           'cute': 1,
#           'delete': 2,
#           'l8r': 1,
#           'haubgirl_': 1,
#           'funniest': 1,
#           'joke': 4,
#           '//haub.suicidegirls.comâ': 1,
#           'dictates': 1,
#           'â€œsevere': 1,
#           'autismâ€\x9d': 2,
#           'epilepsy': 1,
#           'life-threatening': 1,
#           'ideation': 4,
#           'speaking': 6,
#           'severe': 2,
#           'eating': 3,
#           'debilitating': 3,
#           'â€œmildâ€\x9d': 1,
#           'call': 16,
#           '911': 2,
#           'emergencies': 1,
#           'â€œfunctioning': 1,
#           'highâ€\x9d': 1,
#           'serious': 4,
#           'question': 5,
#           'actuallyautistic': 2,
#           'eeek': 1,
#           'hoodies': 1,
#           'embroidering': 1,
#           'photo': 2,
#           '45': 5,
#           'brand': 3,
#           'pennant': 1,
#           'style': 1,
#           'super': 2,
#           'hoodie': 2,
#           'purchase': 2,
#           'american': 5,
#           ...})

# %%
type(fd_nwFinal)
# Out:
# nltk.probability.FreqDist

# %%
type(final_words)
# Out:
# list

# %%
#creating a string/text file with join statement
finalList = ' '.join(final_words)

# %%
finalList
# Out:
# "someone know struggling crisis alone partner lifeline 800273talk help iâ€™ve thinking suicide every single day hate want cut pieces one way ... write headline suicide biggest killer boys 30 country   never talked absolute sin someone might need contacts today suicide 0800567567 rape 0214479762 assault 0861322322 depression 0800121314 emergency 112 adhd helpline 0800554433 trauma line 0800205026 mental health line 0112344837 rippieterhowes pieterhowes fuck everyone dumb shit say suicide fucking hate selfish ass mfs friends prayer request way minister family whose adult son died suicide please ask godâ€™s loving presence thx appreciated dah agak dah cerita ni lebih promote suicide dari bring awareness tapi masa tweet kata tak best many came defence distraught mother warns netflix   13 reasons daughter 12 took lifeâ daily mail online depression isnâ€™t real tell fuck lost one best friends suicide 17. fuck say depression real never ever ever know battles someone fighting head please never forget check loved ones proud music enjoy fuck people think taste woke opens twitter need suicide ou mah gawd suicide answer 2. night double suicide suicide skwad karen fukuhara suicide squad she-ra princesses power boys 26. javert   suicide suicide never answer suicide pit pic.twitter.com/vc2yiqqags hardly home always reppinâ€™ mental health matters month every rt case someone needs contacts suicide crisis helpline 0800 12 13 14 sadag south african depression anxiety group helpline â 0800 567â 567 sms â 31393 lifeline sa helpline â 0861 322â 322 two tone suit like joker harley quinn wears choker let suicide doors ... patiently waiting hoteldiablo urgent prayer father jesus holy spirit one god please save precious younger brother ray17278912 suicidal thoughts attempted suicide please guide people know family seek help urgently jesus holy name mondaymotivation would shorten government reduce indigenous youth suicide qanda russ_lynch iâ€™m new twitter forgive tardy response youâ€™re brave man reporting devastating effects 2019 loan charge commend given editor g. osborne gauke instigated retrospective tax pâ€™se keep investigati shaken suicide silence 22 veterans commit suicide every day mr shekhargupta article afridi writes   field orders india games simple go destroy almost like suicide bomber   allow theprintindia indian say gambhir kaif wrote line sports alexsha67667166 without going war indian army..navy iaf lost 7000+ terrorist indian military personnel since 2015 highest terrorist indian army suicide rate world terroristdeservesdeath please give food bhikhari   dont understand expect apologetic hindu   smritiirani .imo best minister narendramodi   govt threating commit suicide break isnâ€™t right yes youâ€™ll sad yes going hurt canâ€™t threaten kinda thing one shittiest things suicide silence rip mitch lucker best single episode aidan   suicide aftermath one saddest episodes ever aired corrie acting every single cast member raw emotional episode raised much awareness male suicide hope wins award ready conversation suicide rates san tan valley donâ€™t suicide isabelle never works spread around national suicide prevention 1 800 273 8255   ok ok. one 're sensitive topics like depressions suicide read risk hurts readin suicide boy read swear sad think watching fans bits pudil hoops going watched waddle hirst nilsson palmer sheridan go suicide watch weeks makeup filter feels kinda nice happymonday stop killing girlfriends chuka university boy kills girlfriend kemu meru commits suicide guardian 2000-03-03   1966 university california studied physicians attitudes toward sex-change surgery majority preferred desperate patients commit suicide rather undergo genital surgery   richard green head nhs sex change programme pic.twitter.com/g9bxv9t70u mimorguee new favorite dino set day â€œdinosrawr â€\x9d see front page http //suicidegirls.comâ let   say opportunity reccomend one anime enrich someone   life one would 'll start ... orange summary group frie ...

# %%
sid = SentimentIntensityAnalyzer()

# %%
sid.polarity_scores(finalList)
# Out:
# {'compound': -1.0, 'neg': 0.34, 'neu': 0.502, 'pos': 0.158}

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
#I have to create an instance
wordcloud = WordCloud()
wc = wordcloud.generate(finalList)

# %%
# Display the generated imaged
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# lower max_font_size, change the maximum number of word and lighten the background:
wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(finalList)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
